# %% [markdown]
# ## Retas em $V_n$
#
# Vamos aproveitar estes exercícios para falar um pouco do *matplotlib* que é uma biblioteca gráfica que se usa com
# o python. Ela é bem completa e quem tiver interessado pode ver mais no [site oficial do matplotlib](https://matplotlib.org).
# Primeiro vamos carregar a biblioteca em nosso ambiente para usar suas funções.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np # outra biblioteca importante para parte numérica

# %% [markdown]
# ## Exercício 1:
# Uma reta passa pelos pontos $(-3,1)$ e $(1,1)$:

# %%
plt.plot([-3 , 1], [1, 1])

# %%
plt.plot([0,0,1,2,-2],[0,1,2,1,1], "ro")
plt.plot([-3 , 1], [1, 1])

# %% [markdown]
# ## Exercicio 2
#
# Vamos verificar se os pontos $P=(2,1,1)$ $Q=(4,1-1)$ e $R=(3,-1,1)$ estão na mesma reta

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
xs=[2,4,3]
ys=[1,1,-1]
zs=[1,-1,1]
ax.plot3D(xs,ys,zs, 'ro')

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')

# Prepare arrays x, y, z
t = np.linspace(0, 6, 100)
s = np.linspace(0, 1.5, 100)

x = 1+t 
y = 1+2*t
z = 1+3*t
x1= 2+3*s
y1= 1+8*s
z1=  13*s
ax.plot(x, y, z, label="L1")
ax.plot(x1,y1,z1, label="L2")
ax.legend()
